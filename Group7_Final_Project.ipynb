# %% [markdown]
# # Final Project
# *Replace this with the name of your project*

# %% [markdown]
# ## Team Member Names & Contributions
# *Feel free to name your team, but please also include your real names and IDs here. Please specify who in your group worked on which parts of the project.*
#
# - **Captain Marvel**: You know, blowing up things and such.
# - **Ant Man**: Cleverly sneaking into small spaces
# - **Hulk**: AKA The "Muscle"

# %% [markdown]
# ## Abstract

# %% [markdown]
# *Fill in your 3-4 sentence abstract here*

# %% [markdown]
# ## Research Question

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# # Background and Prior Work

# %% [markdown]
# *Fill in your background and prior work here (~500 words). You are welcome to use additional subheadings. You should also include a paragraph describing each dataset and how you'll be using them.*
#
# ### References (include links):
# (1)
#
# (2)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# *Fill in your hypotheses here*

# %% [markdown]
# ## Setup
# *Are there packages that need to be imported, or datasets that need to be downloaded?*

# %%
#Import the necessary toolboxes from the allensdk
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi

#Import necessary packages 
#Plotting packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

#For manipulating data
from scipy import stats
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# At first we have to get the data from the CellTypes database.

# %%
#Initialize the cache as 'ctc' (cell types cache)
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

#We will be using cre-lines to choose excitatory and inhibitory cells from the Cell Types Database 
#so we will only import the mouse cells data api because they haven't created cre-line humans  ........ yet
#With this mouse data we will create a dataframe with the 'id' as its index so we can manipulate it
mouse_df = pd.DataFrame(ctc.get_cells(species=[CellTypesApi.MOUSE]))

#Get the physiology data and make a dataframe with 'specimen_id' the index so the two dataframes can be joined
ephys_features = pd.DataFrame(ctc.get_ephys_features())

#ephys_features.head()

# %% [markdown]
# This cell will explain what we just did.

# %%
#This renames the 'id' column to 'specimen_id' so I don't get a headahce when I try to merge them.
mouse_df = mouse_df.rename(columns={"id": "specimen_id"})

#This picks out the columns for the creline and brain location information we need from the mouse dataframe to use
mouse_crelines_df = mouse_df[['transgenic_line', 'specimen_id', 'structure_layer_name', 'structure_area_abbrev']]

mouse_crelines_df.head()
# Out:
#                     transgenic_line  specimen_id structure_layer_name  \
# 0                      Oxtr-T2A-Cre    565871768                    5
# 1                    Pvalb-IRES-Cre    469801138                    4
# 2  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre    605889373                  2/3
# 3                      Cux2-CreERT2    485909730                    5
# 4                    Scnn1a-Tg3-Cre    323865917                    5
#
#   structure_area_abbrev
# 0                  VISp
# 1                  VISp
# 2                  VISp
# 3                  VISp
# 4                  VISp

# %% [markdown]
# This is just a little step where we merge the data from the CellTypes database and the Electrophysiology database based on the specimen's id so that we have all the data in one place.

# %%
#Here we merge them
mouse_crelines_ephys_data = mouse_crelines_df.merge(ephys_features,on='specimen_id', how='inner')
mouse_crelines_ephys_data.head()
# Out:
#                     transgenic_line  specimen_id structure_layer_name  \
# 0                      Oxtr-T2A-Cre    565871768                    5
# 1                    Pvalb-IRES-Cre    469801138                    4
# 2  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre    605889373                  2/3
# 3                      Cux2-CreERT2    485909730                    5
# 4                    Scnn1a-Tg3-Cre    323865917                    5
#
#   structure_area_abbrev  adaptation    avg_isi  electrode_0_pa  \
# 0                  VISp         NaN        NaN       -2.825000
# 1                  VISp    0.000643  12.507500       27.185625
# 2                  VISp   -0.015098  78.950909       17.437501
# 3                  VISp    0.032340  55.895000      -55.964379
# 4                  VISp    0.026732  94.233500       96.421870
#
#    f_i_curve_slope  fast_trough_t_long_square  fast_trough_t_ramp  ...  \
# 0         0.020384                   1.072500           14.737980  ...
# 1         1.156789                   1.272425           11.763725  ...
# 2         0.191853                   1.879840            8.427893  ...
# 3         0.250000                   1.112495            2.853377  ...
# 4         0.164286                   1.197855            3.423100  ...
#
#    trough_t_ramp  trough_t_short_square  trough_v_long_square  trough_v_ramp  \
# 0      14.738000               1.391268            -59.281254     -57.468754
# 1      11.763808               1.290815            -55.875000     -52.515627
# 2       8.432940               1.315510            -48.187500     -54.364586
# 3       2.888133               1.520193            -54.031254     -57.385419
# 4       3.467847               1.317042            -57.281254     -56.895833
#
#    trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 0             -75.756252                               1.564027
# 1             -69.109379                               1.162618
# 2             -72.640628                               3.379321
# 3             -77.750005                               3.042933
# 4             -70.218751                               2.974194
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        1.304349                                1.679550
# 1                        1.197155                                1.369171
# 2                        4.108774                                2.680139
# 3                        3.517684                                3.274181
# 4                        3.156117                                2.946463
#
#    vm_for_sag      vrest
# 0  -87.906258 -74.926987
# 1  -80.156250 -72.042976
# 2  -83.593758 -72.712036
# 3 -101.000000 -76.928391
# 4  -88.406250 -69.402855
#
# [5 rows x 59 columns]

# %% [markdown]
# We now want to isolate the creline, layer and brain location that we want to compare in the databases.  Here we are isolating the electrophysiological data for Pvalb-IRES-Cre creline inhibitory neurons in layer 4 of the primary visual cortex and Scnn1a-Tg3-Cre also in layer 4 of the primary visual cortex.

# %%
#Each line of code here isolates the rows matching the inhibitory neuron data that we want from the appropiate column
mouse_inhib_df1 = mouse_crelines_ephys_data[(mouse_crelines_ephys_data['transgenic_line'] == 'Pvalb-IRES-Cre')]
mouse_inhib_df2 = mouse_inhib_df1[(mouse_inhib_df1['structure_area_abbrev'] == 'VISp')]
mouse_inhib_ephys = mouse_inhib_df2[(mouse_inhib_df2['structure_layer_name'] == '4')]

mouse_inhib_ephys.head()
# Out:
#     transgenic_line  specimen_id structure_layer_name structure_area_abbrev  \
# 1    Pvalb-IRES-Cre    469801138                    4                  VISp
# 117  Pvalb-IRES-Cre    487405644                    4                  VISp
# 152  Pvalb-IRES-Cre    478793814                    4                  VISp
# 210  Pvalb-IRES-Cre    484744867                    4                  VISp
# 214  Pvalb-IRES-Cre    475894121                    4                  VISp
#
#      adaptation    avg_isi  electrode_0_pa  f_i_curve_slope  \
# 1      0.000643  12.507500       27.185625         1.156789
# 117    0.000996  19.362255      -33.476246         0.772348
# 152    0.003198  17.355714       11.163750         0.716402
# 210    0.006846   4.658478       72.551243         2.111776
# 214         NaN  14.980000        5.502500         0.780911
#
#      fast_trough_t_long_square  fast_trough_t_ramp  ...  trough_t_ramp  \
# 1                     1.272425           11.763725  ...      11.763808
# 117                   1.094250            8.718850  ...       8.718913
# 152                   1.056425           11.896130  ...      11.896288
# 210                   1.024225                 NaN  ...            NaN
# 214                   1.050670                 NaN  ...            NaN
#
#      trough_t_short_square  trough_v_long_square  trough_v_ramp  \
# 1                 1.290815            -55.875000     -52.515627
# 117               1.454521            -58.156250     -56.854168
# 152               1.531172            -59.531254     -59.354168
# 210               1.285388            -74.000000            NaN
# 214               1.729035            -56.281254            NaN
#
#      trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 1               -69.109379                               1.162618
# 117             -70.156253                               1.272070
# 152             -78.781253                               1.393663
# 210             -71.387502                               0.935694
# 214             -77.864586                               1.265073
#
#      upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 1                          1.197155                                1.369171
# 117                        1.266610                                1.404371
# 152                        1.402116                                1.609452
# 210                             NaN                                0.997145
# 214                             NaN                                1.635448
#
#      vm_for_sag      vrest
# 1    -80.156250 -72.042976
# 117  -85.468758 -69.590126
# 152  -95.343750 -78.447914
# 210 -100.875008 -70.245308
# 214  -99.187508 -78.509483
#
# [5 rows x 59 columns]

# %%
#Each line of code here isolates the rows matching the inhibitory neuron data that we want from the appropiate column
mouse_excit_df1 = mouse_crelines_ephys_data[(mouse_crelines_ephys_data['transgenic_line'] == 'Scnn1a-Tg3-Cre')]
mouse_excit_df2 = mouse_excit_df1[(mouse_excit_df1['structure_area_abbrev'] == 'VISp')]
mouse_excit_ephys = mouse_excit_df2[(mouse_excit_df2['structure_layer_name'] == '4')]

mouse_excit_ephys.head()
# Out:
#     transgenic_line  specimen_id structure_layer_name structure_area_abbrev  \
# 8    Scnn1a-Tg3-Cre    476135066                    4                  VISp
# 22   Scnn1a-Tg3-Cre    470098860                    4                  VISp
# 25   Scnn1a-Tg3-Cre    479091820                    4                  VISp
# 65   Scnn1a-Tg3-Cre    515202564                    4                  VISp
# 211  Scnn1a-Tg3-Cre    476269122                    4                  VISp
#
#      adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 8      0.098665  113.287143      -68.804996         0.139337
# 22     0.028417   61.052667       -3.065625         0.227151
# 25     0.258177  104.791667      -10.133750        -0.003381
# 65     0.015462   71.547692      -12.660000         0.141274
# 211         NaN         NaN      -14.635000         0.114082
#
#      fast_trough_t_long_square  fast_trough_t_ramp  ...  trough_t_ramp  \
# 8                     1.151005            5.805325  ...       5.837250
# 22                    1.139550            4.441972  ...       4.464322
# 25                    1.189130            5.958838  ...       5.989438
# 65                    1.239480            5.741353  ...       5.782207
# 211                   1.181900            4.681013  ...       4.717250
#
#      trough_t_short_square  trough_v_long_square  trough_v_ramp  \
# 8                 1.416055            -54.281254     -55.656254
# 22                1.495018            -60.656254     -58.979170
# 25                1.352083            -56.156250     -52.583335
# 65                1.605676            -59.250004     -55.645833
# 211               1.424983            -54.718750     -57.208337
#
#      trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 8               -75.062500                               3.386317
# 22              -80.862502                               3.278334
# 25              -78.898438                               3.139299
# 65              -78.375005                               3.824073
# 211             -76.156255                               3.214515
#
#      upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 8                          3.171764                                3.857029
# 22                         3.049282                                3.712753
# 25                         2.898330                                3.893947
# 65                         3.997622                                3.830650
# 211                        2.789790                                3.783612
#
#      vm_for_sag      vrest
# 8    -87.000008 -75.066132
# 22   -99.187508 -80.129494
# 25   -94.625000 -78.553154
# 65   -92.062500 -77.858864
# 211  -88.687500 -76.060822
#
# [5 rows x 59 columns]

# %% [markdown]
# Not every data set is perfect so some columns have NA instead of actual numbers.  Here we clean up the data so that we don't have to deal with that.

# %% [markdown]
# ## Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
